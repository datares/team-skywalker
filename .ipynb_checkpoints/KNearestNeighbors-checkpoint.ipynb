# %%
import pandas as pd
import numpy as np
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns
import itertools

# %% [markdown]
# ### Using Cleaned Data

# %%
rawData = pd.read_csv("cleanData2.csv")

# %%
rawData = rawData.drop("Unnamed: 0", axis = 1)
rawData
# Out:
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0            -1.061708   1.088639      -0.481497      -0.549001
# 1            -1.061708   1.023635      -0.481497      -0.549001
# 2             0.941878  -1.008242      -0.481497       1.821492
# 3             0.941878  -1.008242      -0.481497       1.821492
# 4            -1.061708   1.088639      -0.481497      -0.549001
# ...                ...        ...            ...            ...
# 9559          0.941878  -1.008242      -0.481497      -0.549001
# 9560          0.941878  -1.008242      -0.481497       1.821492
# 9561         -1.061708   0.033908      -0.481497      -0.549001
# 9562          0.941878  -0.964207      -0.481497      -0.549001
# 9563          0.941878  -1.008242      -0.481497      -0.549001
#
#       koi_fpflag_co  koi_fpflag_ec  koi_period  koi_time0bk  koi_impact  \
# 0         -0.492014      -0.369333   -0.049588     0.064131   -0.175923
# 1         -0.492014      -0.369333   -0.015924    -0.054029   -0.044527
# 2         -0.492014      -0.369333   -0.041787     0.142339    0.069847
# 3         -0.492014      -0.369333   -0.055395     0.060727    0.161526
# 4         -0.492014      -0.369333   -0.054804     0.079692   -0.010185
# ...             ...            ...         ...          ...         ...
# 9559      -0.492014       2.707584   -0.050261    -0.503084    0.008927
# 9560       2.032462      -0.369333   -0.056301    -0.507663    0.154359
# 9561      -0.492014      -0.369333   -0.055393    -0.488578   -0.206682
# 9562       2.032462      -0.369333   -0.056186    -0.500645   -0.175625
# 9563       2.032462       2.707584   -0.053058    -0.444523   -0.179507
#
#       koi_duration  ...   koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  \
# 0        -0.411686  ... -0.341451  -0.048067      -0.281610         -0.366652
# 1        -0.172241  ... -0.750184  -0.048598      -0.294177          1.138156
# 2        -0.593305  ... -0.522461  -0.048408      -0.230716         -0.366652
# 3        -0.496846  ...  0.361570  -0.043052       0.308766         -0.366652
# 4        -0.613039  ...  0.374416  -0.042838      -0.275201         -0.366652
# ...            ...  ...       ...        ...            ...               ...
# 9559     -0.126036  ... -0.182629  -0.047547      -0.316042         -0.366652
# 9560     -0.370797  ...  1.170862  -0.020385       0.243043         -0.366652
# 9561     -0.387502  ...  0.610313  -0.038694      -0.313278         -0.366652
# 9562     -0.735041  ...  1.322677  -0.012766      -0.311141         -0.366652
# 9563     -0.393065  ...  0.210923  -0.044840      -0.316294         -0.366652
#
#       koi_steff  koi_slogg  koi_srad        ra       dec  koi_kepmag
# 0     -0.316037   0.362574 -0.130852 -0.026421  1.202764    0.781300
# 1     -0.316037   0.362574 -0.130852 -0.026421  1.202764    0.781300
# 2      0.183451   0.540575 -0.140482  1.037397  1.200675    0.845542
# 3      0.123211   0.586809 -0.153049 -1.369071  1.242630    0.961756
# 4      0.406841   0.295535 -0.111429 -0.693454  1.226243    0.898236
# ...         ...        ...       ...       ...       ...         ...
# 9559  -0.086373  -0.032726 -0.104574  1.403373  0.878331    0.154033
# 9560  -0.086373   0.505899 -0.134769  1.075986  0.911785   -0.131810
# 9561   0.517281   0.309405 -0.113878 -1.164565  0.931057    0.355423
# 9562   0.585050   0.316340 -0.112246  0.441575  0.934684    0.808729
# 9563   0.956530   0.173015 -0.087437  1.038435  0.919338    0.405229
#
# [9564 rows x 22 columns]

# %%
y = le.fit_transform(rawData['koi_pdisposition'])
y
# Out:
# array([0, 0, 1, ..., 0, 1, 1], dtype=int64)

# %%
X = rawData.drop("koi_pdisposition", axis = 1)
X = X.fillna(0)
X
# Out:
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0      1.088639      -0.481497      -0.549001      -0.492014      -0.369333
# 1      1.023635      -0.481497      -0.549001      -0.492014      -0.369333
# 2     -1.008242      -0.481497       1.821492      -0.492014      -0.369333
# 3     -1.008242      -0.481497       1.821492      -0.492014      -0.369333
# 4      1.088639      -0.481497      -0.549001      -0.492014      -0.369333
# ...         ...            ...            ...            ...            ...
# 9559  -1.008242      -0.481497      -0.549001      -0.492014       2.707584
# 9560  -1.008242      -0.481497       1.821492       2.032462      -0.369333
# 9561   0.033908      -0.481497      -0.549001      -0.492014      -0.369333
# 9562  -0.964207      -0.481497      -0.549001       2.032462      -0.369333
# 9563  -1.008242      -0.481497      -0.549001       2.032462       2.707584
#
#       koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  ...  \
# 0      -0.049588     0.064131   -0.175923     -0.411686  -0.281819  ...
# 1      -0.015924    -0.054029   -0.044527     -0.172241  -0.278670  ...
# 2      -0.041787     0.142339    0.069847     -0.593305  -0.157985  ...
# 3      -0.055395     0.060727    0.161526     -0.496846  -0.191059  ...
# 4      -0.054804     0.079692   -0.010185     -0.613039  -0.281977  ...
# ...          ...          ...         ...           ...        ...  ...
# 9559   -0.050261    -0.503084    0.008927     -0.126036  -0.288243  ...
# 9560   -0.056301    -0.507663    0.154359     -0.370797  -0.270097  ...
# 9561   -0.055393    -0.488578   -0.206682     -0.387502  -0.288720  ...
# 9562   -0.056186    -0.500645   -0.175625     -0.735041  -0.288045  ...
# 9563   -0.053058    -0.444523   -0.179507     -0.393065  -0.288377  ...
#
#        koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  koi_steff  \
# 0    -0.341451  -0.048067      -0.281610         -0.366652  -0.316037
# 1    -0.750184  -0.048598      -0.294177          1.138156  -0.316037
# 2    -0.522461  -0.048408      -0.230716         -0.366652   0.183451
# 3     0.361570  -0.043052       0.308766         -0.366652   0.123211
# 4     0.374416  -0.042838      -0.275201         -0.366652   0.406841
# ...        ...        ...            ...               ...        ...
# 9559 -0.182629  -0.047547      -0.316042         -0.366652  -0.086373
# 9560  1.170862  -0.020385       0.243043         -0.366652  -0.086373
# 9561  0.610313  -0.038694      -0.313278         -0.366652   0.517281
# 9562  1.322677  -0.012766      -0.311141         -0.366652   0.585050
# 9563  0.210923  -0.044840      -0.316294         -0.366652   0.956530
#
#       koi_slogg  koi_srad        ra       dec  koi_kepmag
# 0      0.362574 -0.130852 -0.026421  1.202764    0.781300
# 1      0.362574 -0.130852 -0.026421  1.202764    0.781300
# 2      0.540575 -0.140482  1.037397  1.200675    0.845542
# 3      0.586809 -0.153049 -1.369071  1.242630    0.961756
# 4      0.295535 -0.111429 -0.693454  1.226243    0.898236
# ...         ...       ...       ...       ...         ...
# 9559  -0.032726 -0.104574  1.403373  0.878331    0.154033
# 9560   0.505899 -0.134769  1.075986  0.911785   -0.131810
# 9561   0.309405 -0.113878 -1.164565  0.931057    0.355423
# 9562   0.316340 -0.112246  0.441575  0.934684    0.808729
# 9563   0.173015 -0.087437  1.038435  0.919338    0.405229
#
# [9564 rows x 21 columns]

# %%
train, test, target, target_test = train_test_split(X, y, test_size=0.2, random_state=0) # 80% training, 20% test

# %% [markdown]
# ### K-Nearest Neighbors
# Classify data points based on the labels of the k nearest neighbors.
# 1. Calculate the distances between the data point you want to classify and the other data points.
# 2. Find the k nearest neighbors based on which data points are closest to your data point.
# 3. Determine the label of your data point depending on the frequency of the other labels in the k nearest neighbors.

# %%
dropCols = rawData.filter(regex="flag").columns
dropCols
# Out:
# Index(['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec'], dtype='object')

# %%
X_new = X.drop(dropCols, axis = 1)
X_new
# Out:
#       koi_score  koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  \
# 0      1.088639   -0.049588     0.064131   -0.175923     -0.411686  -0.281819
# 1      1.023635   -0.015924    -0.054029   -0.044527     -0.172241  -0.278670
# 2     -1.008242   -0.041787     0.142339    0.069847     -0.593305  -0.157985
# 3     -1.008242   -0.055395     0.060727    0.161526     -0.496846  -0.191059
# 4      1.088639   -0.054804     0.079692   -0.010185     -0.613039  -0.281977
# ...         ...         ...          ...         ...           ...        ...
# 9559  -1.008242   -0.050261    -0.503084    0.008927     -0.126036  -0.288243
# 9560  -1.008242   -0.056301    -0.507663    0.154359     -0.370797  -0.270097
# 9561   0.033908   -0.055393    -0.488578   -0.206682     -0.387502  -0.288720
# 9562  -0.964207   -0.056186    -0.500645   -0.175625     -0.735041  -0.288045
# 9563  -1.008242   -0.053058    -0.444523   -0.179507     -0.393065  -0.288377
#
#       koi_prad   koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  \
# 0    -0.032699 -0.341451  -0.048067      -0.281610         -0.366652
# 1    -0.032514 -0.750184  -0.048598      -0.294177          1.138156
# 2    -0.028690 -0.522461  -0.048408      -0.230716         -0.366652
# 3    -0.022561  0.361570  -0.043052       0.308766         -0.366652
# 4    -0.032540  0.374416  -0.042838      -0.275201         -0.366652
# ...        ...       ...        ...            ...               ...
# 9559 -0.033073 -0.182629  -0.047547      -0.316042         -0.366652
# 9560 -0.023897  1.170862  -0.020385       0.243043         -0.366652
# 9561 -0.033200  0.610313  -0.038694      -0.313278         -0.366652
# 9562 -0.033086  1.322677  -0.012766      -0.311141         -0.366652
# 9563 -0.033093  0.210923  -0.044840      -0.316294         -0.366652
#
#       koi_steff  koi_slogg  koi_srad        ra       dec  koi_kepmag
# 0     -0.316037   0.362574 -0.130852 -0.026421  1.202764    0.781300
# 1     -0.316037   0.362574 -0.130852 -0.026421  1.202764    0.781300
# 2      0.183451   0.540575 -0.140482  1.037397  1.200675    0.845542
# 3      0.123211   0.586809 -0.153049 -1.369071  1.242630    0.961756
# 4      0.406841   0.295535 -0.111429 -0.693454  1.226243    0.898236
# ...         ...        ...       ...       ...       ...         ...
# 9559  -0.086373  -0.032726 -0.104574  1.403373  0.878331    0.154033
# 9560  -0.086373   0.505899 -0.134769  1.075986  0.911785   -0.131810
# 9561   0.517281   0.309405 -0.113878 -1.164565  0.931057    0.355423
# 9562   0.585050   0.316340 -0.112246  0.441575  0.934684    0.808729
# 9563   0.956530   0.173015 -0.087437  1.038435  0.919338    0.405229
#
# [9564 rows x 17 columns]

# %%
train, test, target, target_test = train_test_split(X_new, y, test_size=0.2, random_state=0) # 80% training, 20% test

# %%
knn = KNeighborsClassifier(n_neighbors = 12)
knn.fit(train, target)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %%
knn_pred = knn.predict(test)
metrics.accuracy_score(target_test, knn_pred)
# Out:
# 0.9257710402509148

# %%
acc = []

for i in range(1, 21):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(train, target)
    knn_pred = knn.predict(test)
    accuracy = metrics.accuracy_score(target_test, knn_pred)
    acc.append(accuracy)
    print(accuracy)
# Out:
# 0.9153162571876634
# 0.894929430214323
# 0.9174072138003136
# 0.909566126502875
# 0.9236800836382645
# 0.9168844746471511
# 0.9262937794040773
# 0.9158389963408259
# 0.9252483010977522
# 0.9236800836382645
# 0.9252483010977522
# 0.9257710402509148
# 0.9289074751698903
# 0.9242028227914271
# 0.9273392577104025
# 0.9226346053319394
# 0.9242028227914271
# 0.9215891270256142
# 0.9262937794040773
# 0.9221118661787768

# %%
plt.plot(range(1, 21), acc, marker = "o", markerfacecolor = "red")
plt.title("K Values and Their Accuracy")
plt.xlabel("K Value")
plt.ylabel("Accuracy")
print("Max accuracy of {} occurs at K = {}".format(max(acc), acc.index(max(acc))))
# Out:
# Max accuracy of 0.9289074751698903 occurs at K = 12

# %%
cv = cross_val_score(knn, train, target)
print(np.mean(cv))
# Out:
# 0.922233492569682

# %%
cv
# Out:
# array([0.91378184, 0.92941176, 0.92614379, 0.92222222, 0.91960784])

# %%
def draw_confusion_matrix(y, yhat, classes):
    '''
        Draws a confusion matrix for the given target and predictions
        Adapted from scikit-learn and discussion example.
    '''
    plt.cla()
    plt.clf()
    matrix = confusion_matrix(y, yhat)
    plt.imshow(matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.colorbar()
    num_classes = len(classes)
    plt.xticks(np.arange(num_classes), classes, rotation=90)
    plt.yticks(np.arange(num_classes), classes)
    
    fmt = 'd'
    thresh = matrix.max() / 2.
    for i, j in itertools.product(range(matrix.shape[0]), range(matrix.shape[1])):
        plt.text(j, i, format(matrix[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if matrix[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %%
draw_confusion_matrix(target_test, knn_pred, ['Exoplanet', 'Not Exoplanet'])
